# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv("Customer Purchasing Behaviors.csv")

# %%
dataset
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# ..       ...  ...            ...              ...            ...    ...
# 233      234   40          60000              450            7.2   West
# 234      235   38          59000              430            6.9  North
# 235      236   54          74000              630            9.4  South
# 236      237   32          52000              360            5.8   West
# 237      238   31          51000              340            5.6  North
#
#      purchase_frequency
# 0                    12
# 1                    18
# 2                    22
# ...

# %%
dataset.isnull().sum()
# Out:
# user_id               0
# age                   0
# annual_income         0
# purchase_amount       0
# loyalty_score         0
# region                0
# purchase_frequency    0
# dtype: int64

# %%
df=dataset

# %%
df.head(3)
# Out:
#    user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0        1   25          45000              200            4.5  North
# 1        2   34          55000              350            7.0  South
# 2        3   45          65000              500            8.0   West
#
#    purchase_frequency
# 0                  12
# 1                  18
# 2                  22

# %%
df.shape
# Out:
# (238, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             238 non-null    int64
#  1   age                 238 non-null    int64
#  2   annual_income       238 non-null    int64
#  3   purchase_amount     238 non-null    int64
#  4   loyalty_score       238 non-null    float64
#  5   region              238 non-null    object
#  6   purchase_frequency  238 non-null    int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 13.1+ KB

# %%
df.nunique()
# Out:
# user_id               238
# age                    34
# annual_income          36
# purchase_amount        36
# loyalty_score          35
# region                  4
# purchase_frequency     19
# dtype: int64

# %%
df.describe()
# Out:
#           user_id         age  annual_income  purchase_amount  loyalty_score  \
# count  238.000000  238.000000     238.000000       238.000000     238.000000
# mean   119.500000   38.676471   57407.563025       425.630252       6.794118
# std     68.848868    9.351118   11403.875717       140.052062       1.899047
# min      1.000000   22.000000   30000.000000       150.000000       3.000000
# 25%     60.250000   31.000000   50000.000000       320.000000       5.500000
# 50%    119.500000   39.000000   59000.000000       440.000000       7.000000
# 75%    178.750000   46.750000   66750.000000       527.500000       8.275000
# max    238.000000   55.000000   75000.000000       640.000000       9.500000
#
#        purchase_frequency
# count          238.000000
# mean            19.798319
# std              4.562884
# min             10.000000
# 25%             17.000000
# 50%             20.000000
# 75%             23.000000
# max             28.000000

# %%
df.head()
# Out:
#    user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0        1   25          45000              200            4.5  North
# 1        2   34          55000              350            7.0  South
# 2        3   45          65000              500            8.0   West
# 3        4   22          30000              150            3.0   East
# 4        5   29          47000              220            4.8  North
#
#    purchase_frequency
# 0                  12
# 1                  18
# 2                  22
# 3                  10
# 4                  13

# %%
df.columns
# Out:
# Index(['user_id', 'age', 'annual_income', 'purchase_amount', 'loyalty_score',
#        'region', 'purchase_frequency'],
#       dtype='object')

# %%
def QuanQual(df):
    Quan=[feature for feature in df.columns if df[feature].dtype!='O']
    Qual=[feature for feature in df.columns if df[feature].dtype=='O']
    return Quan,Qual

# %%
Quan,Qual=QuanQual(df)

# %%
Quan
# Out:
# ['user_id',
#  'age',
#  'annual_income',
#  'purchase_amount',
#  'loyalty_score',
#  'purchase_frequency']

# %%
Qual
# Out:
# ['region']

# %%
import sys
print(sys.path)
# Out:
# ['C:\\Artificial Itelligent\\project', 'C:\\Users\\rsarv\\anaconda3\\python311.zip', 'C:\\Users\\rsarv\\anaconda3\\DLLs', 'C:\\Users\\rsarv\\anaconda3\\Lib', 'C:\\Users\\rsarv\\anaconda3', '', 'C:\\Users\\rsarv\\anaconda3\\Lib\\site-packages', 'C:\\Users\\rsarv\\anaconda3\\Lib\\site-packages\\win32', 'C:\\Users\\rsarv\\anaconda3\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\rsarv\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %%
import sys
sys.path.append('/path/to/your/module')

# %%
from DescriptiveAnalysis import Describe

# %%
result = Describe.FreqTable("annual_income",df)
result
# Out:
#     Unique_values  Frequency  Relative_Frequency    Cumsum
# 0           32000         14            0.135922  0.135922
# 1           53000         14            0.135922  0.271845
# 2           61000         14            0.135922  0.407767
# 3           70000         14            0.135922  0.543689
# 4           46000         14            0.135922  0.679612
# 5           72000          8            0.077670  0.757282
# 6           44000          8            0.077670  0.834951
# 7           52000          8            0.077670  0.912621
# 8           49000          8            0.077670  0.990291
# 9           57000          8            0.077670  1.067961
# 10          69000          8            0.077670  1.145631
# 11          58000          8            0.077670  1.223301
# 12          66000          8            0.077670  1.300971
# 13          59000          8            0.077670  1.378641
# 14          43000          8            0.077670  1.456311
# ...

# %%
result = Describe.FreqTable("purchase_amount",df)
result
# Out:
#     Unique_values  Frequency  Relative_Frequency    Cumsum
# 0             600         21            0.203883  0.203883
# 1             380         14            0.135922  0.339806
# 2             170         14            0.135922  0.475728
# 3             480         14            0.135922  0.611650
# 4             430          8            0.077670  0.689320
# 5             450          8            0.077670  0.766990
# 6             610          8            0.077670  0.844660
# 7             240          8            0.077670  0.922330
# 8             300          8            0.077670  1.000000
# 9             440          8            0.077670  1.077670
# 10            590          8            0.077670  1.155340
# 11            420          8            0.077670  1.233010
# 12            510          8            0.077670  1.310680
# 13            250          8            0.077670  1.388350
# 14            230          8            0.077670  1.466019
# ...

# %%
import seaborn as sns

# %%
sns.distplot(df["purchase_amount"])
# Out:
# <Axes: xlabel='purchase_amount', ylabel='Density'>
