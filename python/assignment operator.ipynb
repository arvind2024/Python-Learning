# %%
#assignment operator

# %%
numb1=8
numb2=6
print(numb1+numb2)
# Out:
# 14

# %%
name="arvind"
print(name)
# Out:
# arvind

# %%
f=5.7
d=6.4
print(f+d)
# Out:
# 12.100000000000001

# %%
add=numb1+numb2
print(add)
# Out:
# 14

# %%
first_name="arvind"
print(first_name)
# Out:
# arvind

# %%
numb3=22
numb4=33
add=numb3+numb4
print("the addition of two numb")
print("numb3:",numb3)
print("numb4:",numb4)
print("the answre is:",add)
# Out:
# the addition of two numb
# numb3: 22
# numb4: 33
# the answre is: 55
