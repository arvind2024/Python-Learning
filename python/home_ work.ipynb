# %%
#home_work

# %%
age=int(input("enter your age ="))
if(0<age<12):
    print("child")
elif(13<age<18):
    print("adult")
elif(19<age<25):
    print("man or woman")
elif(26<age<50):
    print("citizen")
else:
    print("senior citizen")
# Out:
# enter your age =25
# senior citizen
