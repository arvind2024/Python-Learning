# %%
#control_structure

# %%
#if_condition

# %%
numb1=int(input("enter numb1"))
if(numb1>50):
    print("the numb1 is bigger than 50")
else:
    print("the numb is smaller than50")
# Out:
# enter numb145
# the numb is smaller than50

# %%
numb2=int(input("entre numb2:"))
numb3=int(input("enter numb3:"))
if(numb2>numb3):
    print("the numb2 bigger than numb3")
else:
    print("the numb2 smaller than numb3")
# Out:
# entre numb2:33
# enter numb3:45
# the numb2 smaller than numb3

# %%
#if_elif

# %%
numb4=int(input("enter numb4;"))
numb5=int(input("enter numb5:"))
if(numb4>numb5):
    print("the numb4 bigger than numb5")
else:
    print("the numb4 smaller than numb5")
# Out:
# enter numb4;55
# enter numb5:34
# the numb4 bigger than numb5
