# %%
a=input("entre a")
# Out:
# entre ahi

# %%
print("welcome")
# Out:
# welcome

# %%
number1=int(input("enter number1:"))
number2=int(input("enter number2:"))
add=number1+number2
print("add=",add)
sub=number1-number2
print("sub=",sub)
multiple=number1*number2
print("multiple=",multiple)
divid=number1/number2
print("divid=",divid)
# Out:
# enter number1:50
# enter number2:25
# add= 75
# sub= 25
# multiple= 1250
# divid= 2.0

# %%
bmi_value=float(input("enter BMI"))
if(17.6>bmi_value):
    print("under weight")
elif(17.6<=bmi_value<=23.4):
    print("normal")
elif(35<=bmi_value<-23.4):
    print("obisity class1")
else:
    print("obisity class2")
# Out:
# enter BMI20
# normal

# %%
def bmi_value():
    bmi_value=float(input("enter BMI"))
    if(17.6>bmi_value):
        print("under weight")
    elif(17.6<=bmi_value<=23.4):
        print("normal")
    elif(35<=bmi_value<-23.4):
        print("obisity class1")
    else:
        print("obisity class2")

# %%
bmi_value()
# Out:
# enter BMI20
# normal

# %%
class bmi_value():
    def bmi_value():
        bmi_value=float(input("enter BMI"))
        if(17.6>bmi_value):
            print("under weight")
        elif(17.6<=bmi_value<=23.4):
            print("normal")
        elif(35<=bmi_value<-23.4):
            print("obisity class1")
        else:
            print("obisity class2")
    def odd_even():
        numb=int(input("enter your numb"))
        if numb%2==0:
            print("the given numb is even")
        else:
            print("the given numb is odd ")

# %%
bmi_value.odd_even()
# Out:
# enter your numb4
# the given numb is even
